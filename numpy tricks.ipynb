# %%
# np.sort 
import numpy as np
a=np.random.randint(1,100,15)
a
np.sort(a)
# sorted gives us list thats why use np.sort
# Out:
# array([ 4,  7,  7, 22, 24, 44, 53, 56, 59, 62, 77, 84, 89, 93, 97],
#       dtype=int32)

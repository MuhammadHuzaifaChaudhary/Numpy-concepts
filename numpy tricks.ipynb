# %%
# np.sort 
import numpy as np
a=np.random.randint(1,100,15).reshape(5,3)
np.sort(a,axis=0)
# column wise sorting
# Out:
# array([[35, 14, 16],
#        [40, 22, 36],
#        [45, 41, 71],
#        [80, 56, 90],
#        [93, 99, 90]], dtype=int32)

# %%
# append function
a
# Out:
# array([[80, 22, 90],
#        [93, 56, 16],
#        [45, 41, 36],
#        [35, 14, 90],
#        [40, 99, 71]], dtype=int32)

# %%
np.append(a,100)
# 100 is appened at the end
# Out:
# array([ 80,  22,  90,  93,  56,  16,  45,  41,  36,  35,  14,  90,  40,
#         99,  71, 100])

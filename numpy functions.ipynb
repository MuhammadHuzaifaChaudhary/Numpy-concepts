# %%
import numpy as np

# %%
arr=np.random.random((3,3))
arr=np.round(arr*100)
arr

# np.round gives round off integer .. like we do arr*100 we will get ans in float to get in integer i will use np.round()
# Out:
# array([[74., 66., 71.],
#        [51., 82., 48.],
#        [67., 71., 38.]])

# %%
arr.max()
# Out:
# np.float64(82.0)

# %%
np.max(arr)
# both are same things
# Out:
# np.float64(82.0)

# %%
arr.max(axis=0)
# Out:
# array([74., 82., 71.])

# %%
np.max(arr,axis=0)
# Out:
# array([74., 82., 71.])

# %%
arr.prod(axis=0)
# gives the product of columns
# Out:
# array([252858., 384252., 129504.])

# %%
np.prod(arr,axis=1)
# produt of rows
# Out:
# array([346764., 200736., 180766.])

# %%
np.sin(arr)
# Out:
# array([[-0.98514626, -0.02655115,  0.95105465],
#        [ 0.67022918,  0.31322878, -0.76825466],
#        [-0.85551998,  0.95105465,  0.29636858]])

# %%
np.prod(arr[0])
# Out:
# np.float64(346764.0)

# %%
np.log(arr)
# Out:
# array([[4.30406509, 4.18965474, 4.26267988],
#        [3.93182563, 4.40671925, 3.87120101],
#        [4.20469262, 4.26267988, 3.63758616]])
